# %%
import functions as f
import pandas as pd
import locale
locale.setlocale(locale.LC_TIME, 'pt_BR.utf8')
# Out:
# 'pt_BR.utf8'

# %%
df = f.leTab("Planilha_vitoria.csv")
df
# Out:
#        Estacao        Data    Tx    Tn   Tmed     UR Prec  Eto Insolação
# 0        83648  01/01/1961  32,2  24,0  26,86  73,25  NaN  NaN       6,0  \
# 1        83648  02/01/1961  25,5  23,4  24,42   89,5  1,2  NaN       0,0
# 2        83648  03/01/1961  28,8  22,4  24,78   83,0  7,9  NaN       0,2
# 3        83648  04/01/1961  28,0  22,6  24,68   88,5  1,6  NaN       0,0
# 4        83648  05/01/1961  27,6  23,6  25,46   88,0  0,2  NaN       0,0
# ...        ...         ...   ...   ...    ...    ...  ...  ...       ...
# 19351    83648  13/06/2019  30,0  22,2  25,04   80,5  0,8  NaN       8,4
# 19352    83648  14/06/2019  30,3  22,2  25,38   78,5  0,0  NaN       9,0
# 19353    83648  15/06/2019  28,9  21,6   24,3   80,5  0,0  NaN       3,5
# 19354    83648  16/06/2019  28,5  20,5    NaN   83,0  0,0  NaN       5,2
# 19355    83648  17/06/2019   NaN  20,5    NaN    NaN  0,0  NaN       NaN
#
#       Velocidade do Vento Media
# 0                     3666667,0
# 1                     3333333,0
# 2                     4333333,0
# 3                     2666667,0
# 4                     1666667,0
# ...                         ...
# 19351                       NaN
# 19352                       NaN
# 19353                       NaN
# 19354                       NaN
# 19355                       NaN
#
# [19356 rows x 10 columns]

# %% [markdown]
# Definição do Período a ser Analisado:

# %%
#Seleciona e retorna um intervalo de df
dataInicial = '04/01/1976'
dataFinal = '04/08/1976'
intervalo = f.dataTab(df,dataInicial,dataFinal)

#Seleciona e retorna um df do mes selecionado
mes = '03'
intervaloMes = f.dataMes(df,mes)
intervaloMes

#Seleciona e retorna um df do ano selecionado
ano = '2013'
intervaloAno = f.dataAno(df,ano)
intervaloAno
# Out:
#        Estacao       Data    Tx    Tn   Tmed     UR Prec  Eto Insolação
# 16997    83648 2013-01-01  32,9  24,6  27,78    NaN  0,0  NaN       9,9  \
# 16998    83648 2013-01-02  32,9  25,0  28,22    NaN  0,0  NaN      10,1
# 16999    83648 2013-01-03  32,5  25,4  28,14    NaN  0,0  NaN       9,9
# 17000    83648 2013-01-04  33,3  24,5  27,96    NaN  0,0  NaN       8,6
# 17001    83648 2013-01-05  32,8  24,9  28,14    NaN  0,0  NaN       8,4
# ...        ...        ...   ...   ...    ...    ...  ...  ...       ...
# 17357    83648 2013-12-27  31,9  23,0  27,06  74,25  0,0  NaN      10,7
# 17358    83648 2013-12-28  31,9  23,2  27,22  75,25  0,0  NaN       9,2
# 17359    83648 2013-12-29  32,9  24,5  27,92  76,75  0,0  NaN       9,0
# 17360    83648 2013-12-30  32,0  24,4  27,56   72,0  7,9  NaN       9,9
# 17361    83648 2013-12-31  32,9  24,8  27,94  71,75  0,0  NaN      10,1
#
#       Velocidade do Vento Media Mês   Ano
# 16997                       3,0  01  2013
# 16998                       2,5  01  2013
# 16999                       2,5  01  2013
# 17000                       1,0  01  2013
# 17001                       2,5  01  2013
# ...                         ...  ..   ...
# 17357                 3666667,0  12  2013
# 17358                 3666667,0  12  2013
# 17359                 2333333,0  12  2013
# 17360                       4,0  12  2013
# 17361                 3333333,0  12  2013
#
# [365 rows x 12 columns]

# %% [markdown]
# Media das temperaturas (Tx,Tn,Tmed,UR,Prec,Evap,Insolação)

# %%
#Seleciona e retorna a media de um intervalo especifico
intervaloMedia = f.calc_especifica(intervalo)
intervaloMedia
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\bruno.silva\.conda\envs\geo_env\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File c:\Users\bruno.silva\.conda\envs\geo_env\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\bruno.silva\.conda\envs\geo_env\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Evap'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 #Seleciona e retorna a media de um intervalo especifico
# ----> 2 intervaloMedia = f.calc_especifica(intervalo)
#       3 intervaloMedia
#
# File c:\Users\bruno.silva\Desktop\dados_historicos\functions.py:47, in calc_especifica(intervaloData)
#      45 # Realiza o calculo da media para cada coluna
#      46 for column in colunas:
# ---> 47     coluna = intervaloData[column].str.replace(',', '.') # Substituir todas as vírgulas por pontos em uma coluna específica
#      48     coluna = pd.to_numeric(coluna, errors='coerce') #elimina valores ausentes na coluna
#      49     coluna = coluna.dropna() #Isola a coluna especificada
#
# File c:\Users\bruno.silva\.conda\envs\geo_env\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\bruno.silva\.conda\envs\geo_env\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'Evap'

# %%
#Seleciona e retorna a media dos meses de determinado ano
intervaloMesAno = f.calc_meses_ano(intervaloAno)
intervaloMesAno
# Out:
#           Tx         Tn       Tmed         UR   Prec   Evap  Insolação Mês
# 0        NaN        NaN        NaN        NaN    0.0    0.0        NaN  01
# 0  35.096154  23.107692  28.090000  67.634615  117.2   97.0   9.350000  02
# 0  33.774074  23.207407  27.187407  75.555556  133.6   84.0   6.641935  03
# 0  31.048000  20.540000  24.813600  75.640000   59.2   67.4   6.453333  04
# 0  29.974074  18.707407  23.278519  80.083333   39.2   74.0   6.016129  05
# 0  29.703846  17.723077  22.560769  85.961538   27.6   56.0   6.043333  06
# 0  29.807692  17.492308  22.264615  80.230769    2.4   74.9   6.419355  07
# 0  30.911111  17.018519  22.812593  75.000000    7.2   99.6   7.674194  08
# 0  31.484615  18.946154  24.023077  77.346154   30.8  104.9   6.806667  09
# 0  30.792308  19.980769  24.423846  79.307692  122.6   86.6   5.374194  10
# 0  31.788462  21.111538  25.807692  77.576923  171.2   86.1   6.320000  11
# 0  31.744828  22.772414  26.453793  84.400000  822.4   63.0   5.677419  12

# %%
#Seleciona e retorna a media de todos os anos
intervaloMesAno = f.calc_anos(df)
intervaloMesAno
# Out:
#           Tx         Tn       Tmed         UR    Prec    Evap  Insolação   Ano
# 0  31.201093  19.408743  24.814208  70.342896  1652.8  1229.3   7.185519  1976
# 0  31.222192  18.500548  24.589534  74.210274  1206.7  1290.6   7.003562  1977
# 0  30.394521  18.053973  24.029260  77.768493  1259.8  1047.3   6.212637  1978
# 0  30.802857  19.255114  24.194091  69.895749  1304.6   839.7   5.781481  1979
# 0  31.011019  19.736066  24.235666  73.327186  1138.2  1048.1   6.471858  1980
# 0  30.079834  19.400000  23.822024  76.688356  1327.8  1011.6   5.901918  1981
# 0  30.878022  19.716712  24.286378  78.096685   811.4  1070.0   6.145753  1982
